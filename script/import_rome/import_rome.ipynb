# %%
import psycopg2
from dotenv import load_dotenv
import pandas as pd
import os
from sqlalchemy import create_engine


load_dotenv('../settings/.env')

# Global variables
db_name = "radar_metier"
db_schema = "radar_metier"
db_connection = None
db_cursor = None
current_file = ""

print("Env:", os.getenv("DB_HOST"),
 os.getenv("DB_PORT"),
 os.getenv("DB_USER"),
 os.getenv("DB_PASSWORD"))
# Out:
# Env: localhost 5432 admin admin123

# %%
import psycopg2
from dotenv import load_dotenv
import pandas as pd
import os
from sqlalchemy import create_engine


load_dotenv('../settings/.env')

# Global variables
db_name = "radar_metier"
db_schema = "radar_metier"
db_connection = None
db_cursor = None
current_file = ""

print("Env:", os.getenv("DB_HOST"),
 os.getenv("DB_PORT"),
 os.getenv("DB_USER"),
 os.getenv("DB_PASSWORD"))

def init_db():
    global db_connection
    global db_cursor

    # Connect to an existing database
    try:
        db_connection = psycopg2.connect(
            host=os.getenv("DB_HOST"),
            port=os.getenv("DB_PORT"),
            database='crypto_db',
            user=os.getenv("DB_USER"),
            password=os.getenv("DB_PASSWORD"))

    except Exception as e:
        print(e)

    # Open a cursor to perform database operations
    try:
        db_cursor = db_connection.cursor()
        print("connection and cursor are created")
    except Exception as e:
        print(e)


def insert_db_data(table_name, data_frame):
    engine = create_engine(f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:{os.getenv('DB_PORT')}/{db_name}")
    try:
        data_frame.to_sql(table_name, engine, if_exists='replace', index=False)
    except Exception as e:
        print(e)


def extract(src_file):
    df = ''
    try:
        df = pd.read_csv(src_file)
    except Exception as e:
        print(e)

    print("Récupération des données depuis le fichier terminée!")

    return df


def transform(data_frame):
    # Concerver les colonnes voulues
    return data_frame


def load(data_frame):
    global current_file
    dest_file = "rome.csv"

    # Sauvegarder le résultat dans un fichier csv
    data_frame.to_csv(dest_file)
    print("Chargement des données dans fichier CSV: ok")

    insert_db_data('test_rome', data_frame)


def main():
    global current_file

    print("--- Insert ROME data ---")
    current_file = '/Users/stephane/Documents/Formation - Data 0325/Projet fil rouge/Data/Code ROME/RefRomeCsv/unix_domaine_professionnel_v458_utf8.csv'

    init_db()

    data_frame = extract(current_file)
    print(data_frame)
#    data_frame = transform(data_frame)
#    load(data_frame)


if __name__ == "__main__":
    main()
# Out:
# Env: localhost 5432 admin admin123
# --- Insert ROME data ---
# connection and cursor are created
# Récupération des données depuis le fichier terminée!
